# %% [markdown]
# # 🛰️ SatQuery AI — GeoChat-7B GPU Inference Backend
#
# This Google Colab notebook runs **GeoChat-7B** (MBZUAI/geochat-7b) on a GPU runtime with FastAPI and Cloudflare Tunnel.
#
# ### ⚡ Quick Start:
# 1. Ensure Hardware Accelerator is set to **GPU** (`Runtime` → `Change runtime type` → `T4 GPU` or `A100 GPU`).
# 2. Click **Runtime** → **Run all** (or run cells sequentially).
# 3. Copy the output `GEOCHAT_API_URL` into your SatQuery `.env` file!

# %%
# Step 1: Verify GPU
# !nvidia-smi

# %%
# Step 2: Install dependencies and cloudflared tunnel
# %%bash
wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
dpkg -i cloudflared-linux-amd64.deb

pip install -q fastapi uvicorn[standard] python-multipart pydantic requests Pillow
pip install -q torch torchvision --index-url https://download.pytorch.org/whl/cu121
pip install -q transformers==4.36.2 accelerate bitsandbytes sentencepiece einops

# %%
# Step 3: Clone SatQuery AI repository
# !git clone https://github.com/RishikGuthula/SatQuery-AI.git /content/SatQuery-AI 2>/dev/null || (cd /content/SatQuery-AI && git pull)

# %%
# Step 4: Run One-Click GeoChat-7B GPU Server & Tunnel
# !python3 /content/SatQuery-AI/geochat_server/colab_runner.py
